# %%
# Condicionales
nom1= 'ana'
nom2= "Ana"

print( nom1 == nom2)
# Out:
# False

# %%
edad= 18

if edad < 18:
    print('Es menor de edad')

else:
    print("Es mayor de edad")
# Out:
# Es mayor de edad

# %%
#Challenge 1

#Escribe un programa que pregunte al usuario por su edad y determine si tiene edad suficiente para comprar y consumir alcohol.
#Si el usuario tiene mas de 18 pero menos de 21 impirmir "Podes tomar pero no comprar"
#Si el usuario tiene menos de 18 imprimir "Juguito nomas"
#Si el usuario tiene mas de 21 imprimir "Hace lo que quieras"



edad_dudosa= int(input("Ingrese su edad"))
print(f'La edad ingresada fue: {edad_dudosa}')



if edad_dudosa < 18:
    print('Juguito nomas')
elif edad_dudosa >= 18:
    print('Podes tomar pero no comprar')
else:
    print('Hace lo que quieras')
# Out:
# La edad ingresada fue: 19
# Podes tomar pero no comprar

# %%
#Escribir un programa en el que se pregunte al usuario por una temperatura (en grados Celsius), imprima la temperatura escrita, y luego clasificar la temperatura ingresada en los siguientes niveles:

# Entre -10 y 18 grados, que imprima "Fresquete".
# Entre 19 y 30 grados, que imprima "Calor'i".
# Entre 31 y 45 grados, que imprima "Hakuuuuuu".
# Para todo lo demás, imprimir "Ñamano mba'e!".

temperatura= int(input('Ingrese la temperatura'))
print(f'La temperatura ingresada fue {temperatura}°C')
 
if temperatura >= -10 and temperatura <= 18:
    print('Fresquete')

elif temperatura >= 19 and temperatura <= 30:
    print("Calor'i")

elif temperatura >= 31 and temperatura <= 45:
    print('Hakuuuuu')

else:
    print("Ñamano mba'e")

temperatura= str(temperatura)
# Out:
# La temperatura ingresada fue 57°C
# Ñamano mba'e

# %%
#   Escribir un programa que almacene una contraseña en una variable, y pregunte al usuario por la contraseña hasta que introduzca la contraseña correcta.

# Cuando el usuario ingrese la contrasena correcta, imprimir un mensaje secreto.

contraseña= "contra123"
contraseña_ingresada= "password"

while contraseña_ingresada != contraseña:
    contraseña_ingresada= input(f'Ingrese la contraseña')
    print('La contraseña es incorrecta')

print("Contraseña correcta")
print("Pengu")
# Out:
# La contraseña es incorrecta
# La contraseña es incorrecta
# La contraseña es incorrecta
# La contraseña es incorrecta
# El mensaje secreto es orange

# %%
lista_componentes= ['teclado', 'mouse', 'monitor', 'disco duro']
print(lista_componentes)

lista_componentes.append("placa")
print(lista_componentes)

lista_componentes[1] = 'lector de discos'
print(lista_componentes)

lista_componentes.pop(2) 
print(lista_componentes)
# Out:
# ['teclado', 'mouse', 'monitor', 'disco duro']
# ['teclado', 'mouse', 'monitor', 'disco duro', 'placa']
# ['teclado', 'lector de discos', 'monitor', 'disco duro', 'placa']
# ['teclado', 'lector de discos', 'disco duro', 'placa']

# %%
for i in range(10):
    print(f'El numero {i} fue multiplicado por 2 dando por resultado {i*2}')
# Out:
# El numero 0 fue multiplicado por 2 dando por resultado 0
# El numero 1 fue multiplicado por 2 dando por resultado 2
# El numero 2 fue multiplicado por 2 dando por resultado 4
# El numero 3 fue multiplicado por 2 dando por resultado 6
# El numero 4 fue multiplicado por 2 dando por resultado 8
# El numero 5 fue multiplicado por 2 dando por resultado 10
# El numero 6 fue multiplicado por 2 dando por resultado 12
# El numero 7 fue multiplicado por 2 dando por resultado 14
# El numero 8 fue multiplicado por 2 dando por resultado 16
# El numero 9 fue multiplicado por 2 dando por resultado 18

# %%
lista_marcas= ['puma', 'adidas', 'nike', 'nestle']

for marcas in lista_marcas:
    if len(marcas) >=6:
     print(marcas)
# Out:
# adidas
# nestle

# %%
frase= input(f'Ingrese una frase')


for letras in frase:
    if letras == 'o':
     print(f'Se ha encontrado la letra o')
# Out:
# Se ha encontrado la letra o
# Se ha encontrado la letra o
